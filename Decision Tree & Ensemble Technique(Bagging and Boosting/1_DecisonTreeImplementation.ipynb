# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Social_Network_Ads.csv")

# %%
features = data.iloc[:,[0,1]].values
label = data.iloc[:,[2]].values

# %%
CL = 0.9

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier # Classification use-cases
#from sklearn.tree import DecisionTreeRegressor # Regression use-case

for i in range(1,301):
  X_train,X_test,y_train,y_test = train_test_split(features,
                                                   label,
                                                   test_size=0.2,
                                                   random_state=i)

  model = DecisionTreeClassifier()

  model.fit(X_train,y_train)

  trainScore = model.score(X_train,y_train)
  testScore = model.score(X_test,y_test)

  #if testScore > trainScore and testScore >= CL:
  print(f"Test Score is {testScore} and Train Score is {trainScore} in Random State seed {i}")
# Out:
# Test Score is 0.8 and Train Score is 0.996875 in Random State seed 1
# Test Score is 0.85 and Train Score is 1.0 in Random State seed 2
# Test Score is 0.8375 and Train Score is 0.99375 in Random State seed 3
# Test Score is 0.8625 and Train Score is 0.99375 in Random State seed 4
# Test Score is 0.875 and Train Score is 0.99375 in Random State seed 5
# Test Score is 0.85 and Train Score is 0.996875 in Random State seed 6
# Test Score is 0.8 and Train Score is 1.0 in Random State seed 7
# Test Score is 0.8625 and Train Score is 1.0 in Random State seed 8
# Test Score is 0.9 and Train Score is 0.996875 in Random State seed 9
# Test Score is 0.85 and Train Score is 0.99375 in Random State seed 10
# Test Score is 0.8625 and Train Score is 0.996875 in Random State seed 11
# Test Score is 0.7875 and Train Score is 0.99375 in Random State seed 12
# Test Score is 0.8625 and Train Score is 0.996875 in Random State seed 13
# ...

# %%
#Observations
# 1. Decision Tree algo is best when it comes to getting OVERFITTED MODEL.
# 2. Decision Tree by default tends to OVERFIT (Learns the known data perfectly, but maynot learn populations
# pattern perfectly)

# %%
CL = 0.9

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier # Classification use-cases
#from sklearn.tree import DecisionTreeRegressor # Regression use-case

for i in range(1,301):
  for depthCheck in range(3,11):

    X_train,X_test,y_train,y_test = train_test_split(features,
                                                   label,
                                                   test_size=0.2,
                                                   random_state=i)

    model = DecisionTreeClassifier(max_depth=depthCheck)

    model.fit(X_train,y_train)

    trainScore = model.score(X_train,y_train)
    testScore = model.score(X_test,y_test)

    if testScore > trainScore and testScore >= CL:
      print(f"Test Score is {testScore} and Train Score is {trainScore} in depth={depthCheck} and  Random State seed {i}")
# Out:
# Test Score is 0.925 and Train Score is 0.909375 in depth=3 and  Random State seed 5
# Test Score is 0.95 and Train Score is 0.91875 in depth=4 and  Random State seed 6
# Test Score is 0.925 and Train Score is 0.915625 in depth=3 and  Random State seed 7
# Test Score is 0.925 and Train Score is 0.9125 in depth=3 and  Random State seed 10
# Test Score is 0.9375 and Train Score is 0.909375 in depth=3 and  Random State seed 18
# Test Score is 0.925 and Train Score is 0.91875 in depth=3 and  Random State seed 21
# Test Score is 0.9375 and Train Score is 0.896875 in depth=3 and  Random State seed 24
# Test Score is 0.925 and Train Score is 0.909375 in depth=3 and  Random State seed 30
# Test Score is 0.9375 and Train Score is 0.915625 in depth=3 and  Random State seed 33
# Test Score is 0.9375 and Train Score is 0.925 in depth=4 and  Random State seed 33
# Test Score is 0.9375 and Train Score is 0.928125 in depth=5 and  Random State seed 33
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(features,
                                                   label,
                                                   test_size=0.2,
                                                   random_state=153)

model = DecisionTreeClassifier(max_depth=5)

model.fit(X_train,y_train)

trainScore = model.score(X_train,y_train)
testScore = model.score(X_test,y_test)


print(f"Test Score is {testScore} and Train Score is {trainScore}")
# Out:
# Test Score is 0.9625 and Train Score is 0.93125

# %%
#Visualize DT

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(100,100)) #Zoom Feature
plot_tree(model,filled=True, feature_names=['age','salary'], class_names=['0','1'])
plt.show()

# %%
# Hyperparameter Tuning ----> Playing with Algo Parameters
# Two parameters that you can play with, with an intention to discover generalized model
# a. max_depth ----> Guideline (Start with 3 to n where n is natural number)
# b. criterion ----> Classification ---> gini, entropy, logloss

# %%
CL = 0.9

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier # Classification use-cases
#from sklearn.tree import DecisionTreeRegressor # Regression use-case

for i in range(1,301):
  for depthCheck in range(3,11):

    X_train,X_test,y_train,y_test = train_test_split(features,
                                                   label,
                                                   test_size=0.2,
                                                   random_state=i)

    model = DecisionTreeClassifier(max_depth=depthCheck, criterion="log_loss")

    model.fit(X_train,y_train)

    trainScore = model.score(X_train,y_train)
    testScore = model.score(X_test,y_test)

    if testScore > trainScore and testScore >= CL:
      print(f"Test Score is {testScore} and Train Score is {trainScore} in depth={depthCheck} and  Random State seed {i}")
# Out:
# Test Score is 0.9375 and Train Score is 0.90625 in depth=3 and  Random State seed 2
# Test Score is 0.925 and Train Score is 0.921875 in depth=4 and  Random State seed 3
# Test Score is 0.925 and Train Score is 0.909375 in depth=3 and  Random State seed 5
# Test Score is 0.95 and Train Score is 0.91875 in depth=4 and  Random State seed 6
# Test Score is 0.925 and Train Score is 0.9125 in depth=3 and  Random State seed 7
# Test Score is 0.925 and Train Score is 0.9125 in depth=3 and  Random State seed 9
# Test Score is 0.925 and Train Score is 0.9125 in depth=3 and  Random State seed 10
# Test Score is 0.925 and Train Score is 0.91875 in depth=4 and  Random State seed 10
# Test Score is 0.9375 and Train Score is 0.90625 in depth=3 and  Random State seed 18
# Test Score is 0.925 and Train Score is 0.915625 in depth=3 and  Random State seed 21
# Test Score is 0.9375 and Train Score is 0.896875 in depth=3 and  Random State seed 24
# ...

# %%
# 50_Startups Dataset
# DecisionTreeRegressor ---->
